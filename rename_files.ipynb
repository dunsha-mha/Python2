# %%
import os

def rename_files():
    #(1) get file names from a folder.
    file_list = os.listdir("/Users/malves/Downloads/prank")
    #print(file_list)

    saved_path = os.getcwd()
    print("Current working directory is "+saved_path)
    os.chdir("/Users/malves/Downloads/prank")

    #(2) for each file, rename filename
    for file_name in file_list:
        print("Old Name - "+file_name)
        print("New Name - "+file_name.translate(None, "01223456789")+"\n")
       # print("Old Name - "+file_nam)
        os.rename(file_name, file_name.translate(None, "01223456789"))
os.chdir(saved_path)    
    
rename_files()
# Out:
# Current working directory is /Users/malves/Downloads/prank
# Old Name - gainesville.jpg
# New Name - gainesville.jpg
#
# Old Name - tel aviv.jpg
# New Name - tel aviv.jpg
#
# Old Name - houston.jpg
# New Name - houston.jpg
#
# Old Name - shanghai.jpg
# New Name - shanghai.jpg
#
# Old Name - oakland.jpg
# New Name - oakland.jpg
#
# Old Name - seattle.jpg
# New Name - seattle.jpg
#
# Old Name - .DS_Store
# New Name - .DS_Store
#
# Old Name - sunnyvale.jpg
# New Name - sunnyvale.jpg
#
# Old Name - athens.jpg
# New Name - athens.jpg
#
# Old Name - sao paulo.jpg
# New Name - sao paulo.jpg
#
# Old Name - beijing.jpg
# New Name - beijing.jpg
#
# Old Name - london.jpg
# New Name - london.jpg
#
# Old Name - chicago.jpg
# New Name - chicago.jpg
#
# Old Name - kiev.jpg
# New Name - kiev.jpg
#
# Old Name - barcelona.jpg
# New Name - barcelona.jpg
#
# Old Name - bucharest.jpg
# New Name - bucharest.jpg
#
# Old Name - berkeley.jpg
# New Name - berkeley.jpg
#
# Old Name - seoul.jpg
# ...
